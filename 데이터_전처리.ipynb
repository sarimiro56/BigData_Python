# %% [markdown]
# <a href="https://colab.research.google.com/github/sarimiro56/BigData_Python/blob/main/%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%A0%84%EC%B2%98%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'A': [1, 2, np.nan, 4, 5],
  'B': [6, 7, 8, np.nan, 10],
  'C': [11, 12, 13, np.nan, np.nan]})
df
# Out:
#      A     B     C
# 0  1.0   6.0  11.0
# 1  2.0   7.0  12.0
# 2  NaN   8.0  13.0
# 3  4.0   NaN   NaN
# 4  5.0  10.0   NaN

# %%
pd.isna(df)
# Out:
#        A      B      C
# 0  False  False  False
# 1  False  False  False
# 2   True  False  False
# 3  False   True   True
# 4  False  False   True

# %%
pd.isna(df).sum( )
# Out:
# A    1
# B    1
# C    2
# dtype: int64

# %%
df_drop_nan = df.dropna( )
df_drop_nan
# Out:
#      A    B     C
# 0  1.0  6.0  11.0
# 1  2.0  7.0  12.0

# %%
df_0 = df['C'].fillna(0)
print(df_0)
# Out:
# 0    11.0
# 1    12.0
# 2    13.0
# 3     0.0
# 4     0.0
# Name: C, dtype: float64

# %%
df_missing = df['A'].fillna('missing')
df_missing
# Out:
# 0        1.0
# 1        2.0
# 2    missing
# 3        4.0
# 4        5.0
# Name: A, dtype: object

# %%
# df.fillna(df.mean( ), inplace=True)
df_mean = df.fillna(df.mean( ))
print(df, '\n')
print(df_mean)
# Out:
#      A     B     C
# 0  1.0   6.0  11.0
# 1  2.0   7.0  12.0
# 2  NaN   8.0  13.0
# 3  4.0   NaN   NaN
# 4  5.0  10.0   NaN
#
#      A      B     C
# 0  1.0   6.00  11.0
# 1  2.0   7.00  12.0
# 2  3.0   8.00  13.0
# 3  4.0   7.75  12.0
# 4  5.0  10.00  12.0

# %%
print(df, '\n')
#결측치 바로 위의 값으로 대체하기
df_ffill = df.fillna(method='ffill')
print(df_ffill, '\n')
#결측치 바로 아래의 값으로 대체하기
df_bfill = df.fillna(method='bfill')
print(df_bfill)
# Out:
#      A     B     C
# 0  1.0   6.0  11.0
# 1  2.0   7.0  12.0
# 2  NaN   8.0  13.0
# 3  4.0   NaN   NaN
# 4  5.0  10.0   NaN
#
#      A     B     C
# 0  1.0   6.0  11.0
# 1  2.0   7.0  12.0
# 2  2.0   8.0  13.0
# 3  4.0   8.0  13.0
# 4  5.0  10.0  13.0
#
#      A     B     C
# 0  1.0   6.0  11.0
# 1  2.0   7.0  12.0
# 2  4.0   8.0  13.0
# 3  4.0  10.0   NaN
# 4  5.0  10.0   NaN

# %%
fill_dict = {'A': df['A'].mean( ), 'B': '12/25', 'C': 'missing'}
df_filled = df.fillna(value=fill_dict)
df_filled
# Out:
#      A      B        C
# 0  1.0    6.0     11.0
# 1  2.0    7.0     12.0
# 2  3.0    8.0     13.0
# 3  4.0  12/25  missing
# 4  5.0   10.0  missing
